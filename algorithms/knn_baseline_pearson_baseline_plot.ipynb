# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def round_est_values(df):
    round_actual = np.round(df["est"], decimals=0)
    round_actual = round_actual.reset_index()
    df = df.reset_index()[["index", "actual", "details"]]
    df = df.merge(round_actual, on="index", how="left")
    df = df.set_index("index")
    grouped = df.groupby("est", as_index=False).count()
    return grouped

# %%
pearson_baseline_fold_0 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_baseline_0.parquet")
pearson_baseline_fold_1 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_baseline_1.parquet")
pearson_baseline_fold_2 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_baseline_2.parquet")
pearson_baseline_fold_3 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_baseline_3.parquet")
pearson_baseline_fold_4 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_baseline_4.parquet")

df = pd.concat([pearson_baseline_fold_0, pearson_baseline_fold_1, pearson_baseline_fold_2, pearson_baseline_fold_3, pearson_baseline_fold_4])

# %% [markdown]
# ### Pearson Baseline

# %% [markdown]
# Os gráficos são comparativo da nota real VS a nota predita. Filtrando cada nota real (de 1 a 10), quais são as notas preditas por cada algoritmo usando similaridade de pearson baseline

# %%
df_grouped = round_est_values(df)
print(df_grouped)
# Out:
#     est   actual  details
# 0   1.0  3669731  3669731
# 1   2.0   364215   364215
# 2   3.0   370915   370915
# 3   4.0   474475   474475
# 4   5.0   862340   862340
# 5   6.0  2139325  2139325
# 6   7.0  5177680  5177680
# 7   8.0  7338205  7338205
# 8   9.0  4745570  4745570
# 9  10.0  1275520  1275520

# %%
df_grouped.plot.bar(x='est', y='actual', title="Distribuição valores preditos (knn_baseline)")
# Out:
# <AxesSubplot:title={'center':'Distribuição valores preditos (knn_baseline)'}, xlabel='est'>

# %%
df_actual_1 = df.loc[df["actual"] == 1]
plot_pearson_baseline_counter = round_est_values(df_actual_1)
print(plot_pearson_baseline_counter)
# Out:
#     est  actual  details
# 0   1.0     846      846
# 1   2.0     546      546
# 2   3.0     789      789
# 3   4.0    1031     1031
# 4   5.0    1350     1350
# 5   6.0    1423     1423
# 6   7.0    1189     1189
# 7   8.0     707      707
# 8   9.0     304      304
# 9  10.0      66       66

# %%
plot_pearson_baseline_counter.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 1 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 1 counter'}, xlabel='est'>

# %%
df_actual_2 = df.loc[df["actual"] == 2]
plot_pearson_baseline_counter_2 = round_est_values(df_actual_2)
print(plot_pearson_baseline_counter_2)
# Out:
#     est  actual  details
# 0   1.0     291      291
# 1   2.0     451      451
# 2   3.0    1102     1102
# 3   4.0    2011     2011
# 4   5.0    2778     2778
# 5   6.0    2796     2796
# 6   7.0    2080     2080
# 7   8.0     979      979
# 8   9.0     291      291
# 9  10.0      43       43

# %%
plot_pearson_baseline_counter_2.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 2 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 2 counter'}, xlabel='est'>

# %%
df_actual_3 = df.loc[df["actual"] == 3]
plot_pearson_baseline_counter_3 = round_est_values(df_actual_3)
print(plot_pearson_baseline_counter_3)
# Out:
#     est  actual  details
# 0   1.0     342      342
# 1   2.0     398      398
# 2   3.0    1347     1347
# 3   4.0    3551     3551
# 4   5.0    5904     5904
# 5   6.0    6284     6284
# 6   7.0    4317     4317
# 7   8.0    1854     1854
# 8   9.0     428      428
# 9  10.0      51       51

# %%
plot_pearson_baseline_counter_3.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 3 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 3 counter'}, xlabel='est'>

# %%
df_actual_4 = df.loc[df["actual"] == 4]
plot_pearson_baseline_counter_4 = round_est_values(df_actual_4)
print(plot_pearson_baseline_counter_4)
# Out:
#     est  actual  details
# 0   1.0     740      740
# 1   2.0     599      599
# 2   3.0    1538     1538
# 3   4.0    5677     5677
# 4   5.0   13892    13892
# 5   6.0   19548    19548
# 6   7.0   15515    15515
# 7   8.0    6493     6493
# 8   9.0    1471     1471
# 9  10.0     130      130

# %%
plot_pearson_baseline_counter_4.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 4 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 4 counter'}, xlabel='est'>

# %%
df_actual_5 = df.loc[df["actual"] == 5]
plot_pearson_baseline_counter_5 = round_est_values(df_actual_5)
print(plot_pearson_baseline_counter_5)
# Out:
#     est  actual  details
# 0   1.0    1806     1806
# 1   2.0    1291     1291
# 2   3.0    2487     2487
# 3   4.0    7297     7297
# 4   5.0   28869    28869
# 5   6.0   62437    62437
# 6   7.0   57548    57548
# 7   8.0   23828    23828
# 8   9.0    5247     5247
# 9  10.0     493      493

# %%
plot_pearson_baseline_counter_5.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 5 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 5 counter'}, xlabel='est'>

# %%
df_actual_6 = df.loc[df["actual"] == 6]
plot_pearson_baseline_counter_6 = round_est_values(df_actual_6)
print(plot_pearson_baseline_counter_6)
# Out:
#     est  actual  details
# 0   1.0    3749     3749
# 1   2.0    2688     2688
# 2   3.0    4536     4536
# 3   4.0    9259     9259
# 4   5.0   34232    34232
# 5   6.0  135605   135605
# 6   7.0  210169   210169
# 7   8.0  100898   100898
# 8   9.0   20171    20171
# 9  10.0    1721     1721

# %%
plot_pearson_baseline_counter_6.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 6 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 6 counter'}, xlabel='est'>

# %%
df_actual_7 = df.loc[df["actual"] == 7]
plot_pearson_baseline_counter_7 = round_est_values(df_actual_7)
print(plot_pearson_baseline_counter_7)
# Out:
#     est  actual  details
# 0   1.0   10516    10516
# 1   2.0    6897     6897
# 2   3.0   10939    10939
# 3   4.0   18278    18278
# 4   5.0   44416    44416
# 5   6.0  184085   184085
# 6   7.0  628771   628771
# 7   8.0  527176   527176
# 8   9.0  115818   115818
# 9  10.0    8246     8246

# %%
plot_pearson_baseline_counter_7.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 7 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 7 counter'}, xlabel='est'>

# %%
df_actual_8 = df.loc[df["actual"] == 8]
plot_pearson_baseline_counter_8 = round_est_values(df_actual_8)
print(plot_pearson_baseline_counter_8)
# Out:
#     est   actual  details
# 0   1.0    14992    14992
# 1   2.0     9745     9745
# 2   3.0    13865    13865
# 3   4.0    21277    21277
# 4   5.0    38516    38516
# 5   6.0   113585   113585
# 6   7.0   496454   496454
# 7   8.0  1050340  1050340
# 8   9.0   400863   400863
# 9  10.0    31525    31525

# %%
plot_pearson_baseline_counter_8.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 8 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 8 counter'}, xlabel='est'>

# %%
df_actua_9 = df.loc[df["actual"] == 9]
plot_pearson_baseline_counter_9 = round_est_values(df_actua_9)
print(plot_pearson_baseline_counter_9)
# Out:
#     est  actual  details
# 0   1.0   13343    13343
# 1   2.0    7726     7726
# 2   3.0   10388    10388
# 3   4.0   14439    14439
# 4   5.0   22942    22942
# 5   6.0   49257    49257
# 6   7.0  172374   172374
# 7   8.0  576821   576821
# 8   9.0  601449   601449
# 9  10.0   81383    81383

# %%
plot_pearson_baseline_counter_9.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 9 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 9 counter'}, xlabel='est'>

# %%
df_actua_10 = df.loc[df["actual"] == 10]
plot_pearson_baseline_counter_10 = round_est_values(df_actua_10)
print(plot_pearson_baseline_counter_10)
# Out:
#     est  actual  details
# 0   1.0   15285    15285
# 1   2.0    7179     7179
# 2   3.0    8626     8626
# 3   4.0   11205    11205
# 4   5.0   15927    15927
# 5   6.0   26684    26684
# 6   7.0   64217    64217
# 7   8.0  199632   199632
# 8   9.0  425515   425515
# 9  10.0  274079   274079

# %%
plot_pearson_baseline_counter_10.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 10 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 10 counter'}, xlabel='est'>

# %%
round_df = np.round(df["est"], decimals=0)
round_df = round_df.reset_index()
df = df.reset_index()[["index", "actual", "details"]]
df = df.merge(round_df, on="index", how="left")

# %%
df = df.set_index("index")
plot_df = df.groupby("est", as_index=False).count()
print(plot_df)
# Out:
#     est   actual  details
# 0   1.0  3669731  3669731
# 1   2.0   364215   364215
# 2   3.0   370915   370915
# 3   4.0   474475   474475
# 4   5.0   862340   862340
# 5   6.0  2139325  2139325
# 6   7.0  5177680  5177680
# 7   8.0  7338205  7338205
# 8   9.0  4745570  4745570
# 9  10.0  1275520  1275520

# %%
def plot_violin_graph_base(list_of_data, title):
    # Create a figure instance
    fig = plt.figure()
  
    # Create an axes instance
    ax = fig.gca()
    ax.set_title(title)
    # Create the violinplot
    violinplot = ax.violinplot(list_of_data)
    plt.show()

# %% [markdown]
# Gráfico para o estudo de como está distribuição de notas preditas

# %%
est_df = df["est"].tolist()
plot_violin_graph_base(est_df, title="all folds estimation")

# %%
df_grouped = round_est_values(df)
print(df_grouped)
# Out:
#     est     actual    details
# 0   1.0   91743251   91743251
# 1   2.0    9105375    9105375
# 2   3.0    9272875    9272875
# 3   4.0   11861875   11861875
# 4   5.0   21558500   21558500
# 5   6.0   53483125   53483125
# 6   7.0  129442000  129442000
# 7   8.0  183455125  183455125
# 8   9.0  118639250  118639250
# 9  10.0   31888000   31888000

# %%
df_grouped.plot.bar(x='est', y='actual', title="Distribuição valores preditos - knn_baseline")
# Out:
# <AxesSubplot:title={'center':'Distribuição valores preditos - knn_baseline'}, xlabel='est'>

# %% [markdown]
# é notório também que as notas reais estão amis concentradas entre 6 e 8, o que infuencia na predição. O algoritmo tende a acertar mais quando com essas notas e errar com notas entre 1 e 4

# %%
est_df = df["actual"].tolist()
plot_violin_graph_base(est_df, title="all folds actual knn_baseline")

# %% [markdown]
# # Removing negative grades

# %% [markdown]
# ### Cossine

# %%
knn_basic_0 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_baseline_0.parquet")
knn_basic_1 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_baseline_1.parquet")
knn_basic_2 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_baseline_2.parquet")
knn_basic_3 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_baseline_3.parquet")
knn_basic_4 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_baseline_4.parquet")

knn_basic = pd.concat([knn_basic_0, knn_basic_1, knn_basic_2, knn_basic_3, knn_basic_4])

# %%
df_actual_with_filter_1 = knn_basic.loc[knn_basic["actual"] == 1]
df_actual_with_filter_1_plot = round_est_values(df_actual_with_filter_1)
print(df_actual_with_filter_1_plot)
# Out:
#     est  actual  details
# 0   1.0     825      825
# 1   2.0     547      547
# 2   3.0     802      802
# 3   4.0    1095     1095
# 4   5.0    1304     1304
# 5   6.0    1454     1454
# 6   7.0    1188     1188
# 7   8.0     701      701
# 8   9.0     281      281
# 9  10.0      66       66

# %%
df_actual_with_filter_1_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 1 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 1 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_2 = knn_basic.loc[knn_basic["actual"] == 2]
df_actual_with_filter_2_plot = round_est_values(df_actual_with_filter_2)
print(df_actual_with_filter_2_plot)
# Out:
#     est  actual  details
# 0   1.0     303      303
# 1   2.0     441      441
# 2   3.0    1122     1122
# 3   4.0    1994     1994
# 4   5.0    2814     2814
# 5   6.0    2700     2700
# 6   7.0    2107     2107
# 7   8.0     971      971
# 8   9.0     307      307
# 9  10.0      33       33

# %%
df_actual_with_filter_2_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 2 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 2 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_3 = knn_basic.loc[knn_basic["actual"] == 3]
df_actual_with_filter_3_plot = round_est_values(df_actual_with_filter_3)
print(df_actual_with_filter_3_plot)
# Out:
#     est  actual  details
# 0   1.0     364      364
# 1   2.0     364      364
# 2   3.0    1343     1343
# 3   4.0    3628     3628
# 4   5.0    5904     5904
# 5   6.0    6233     6233
# 6   7.0    4299     4299
# 7   8.0    1851     1851
# 8   9.0     423      423
# 9  10.0      53       53

# %%
df_actual_with_filter_3_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 3 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 3 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_4 = knn_basic.loc[knn_basic["actual"] == 4]
df_actual_with_filter_4_plot = round_est_values(df_actual_with_filter_4)
print(df_actual_with_filter_4_plot)
# Out:
#     est  actual  details
# 0   1.0     739      739
# 1   2.0     611      611
# 2   3.0    1560     1560
# 3   4.0    5566     5566
# 4   5.0   14122    14122
# 5   6.0   19551    19551
# 6   7.0   15243    15243
# 7   8.0    6590     6590
# 8   9.0    1413     1413
# 9  10.0     144      144

# %%
df_actual_with_filter_4_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 4 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 4 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_5 = knn_basic.loc[knn_basic["actual"] == 5]
df_actual_with_filter_5_plot = round_est_values(df_actual_with_filter_5)
print(df_actual_with_filter_5_plot)
# Out:
#     est  actual  details
# 0   1.0    1890     1890
# 1   2.0    1302     1302
# 2   3.0    2378     2378
# 3   4.0    7372     7372
# 4   5.0   29071    29071
# 5   6.0   62733    62733
# 6   7.0   57442    57442
# 7   8.0   24028    24028
# 8   9.0    5231     5231
# 9  10.0     484      484

# %%
df_actual_with_filter_5_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 5 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 5 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_6 = knn_basic.loc[knn_basic["actual"] == 6]
df_actual_with_filter_6_plot = round_est_values(df_actual_with_filter_6)
print(df_actual_with_filter_6_plot)
# Out:
#     est  actual  details
# 0   1.0    3700     3700
# 1   2.0    2667     2667
# 2   3.0    4477     4477
# 3   4.0    9365     9365
# 4   5.0   33878    33878
# 5   6.0  136583   136583
# 6   7.0  209223   209223
# 7   8.0  101047   101047
# 8   9.0   20438    20438
# 9  10.0    1670     1670

# %%
df_actual_with_filter_6_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 6 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 6 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_7 = knn_basic.loc[knn_basic["actual"] == 7]
df_actual_with_filter_7_plot = round_est_values(df_actual_with_filter_7)
print(df_actual_with_filter_7_plot)
# Out:
#     est  actual  details
# 0   1.0   10484    10484
# 1   2.0    7040     7040
# 2   3.0   10712    10712
# 3   4.0   18144    18144
# 4   5.0   44740    44740
# 5   6.0  184426   184426
# 6   7.0  628626   628626
# 7   8.0  528519   528519
# 8   9.0  116036   116036
# 9  10.0    8315     8315

# %%
df_actual_with_filter_7_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 7 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 7 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_8 = knn_basic.loc[knn_basic["actual"] == 8]
df_actual_with_filter_8_plot = round_est_values(df_actual_with_filter_8)
print(df_actual_with_filter_8_plot)
# Out:
#     est   actual  details
# 0   1.0    15184    15184
# 1   2.0     9714     9714
# 2   3.0    14191    14191
# 3   4.0    21122    21122
# 4   5.0    38348    38348
# 5   6.0   113904   113904
# 6   7.0   496774   496774
# 7   8.0  1047661  1047661
# 8   9.0   399860   399860
# 9  10.0    31542    31542

# %%
df_actual_with_filter_8_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 8 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 8 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_9 = knn_basic.loc[knn_basic["actual"] == 9]
df_actual_with_filter_9_plot = round_est_values(df_actual_with_filter_9)
print(df_actual_with_filter_9_plot)
# Out:
#     est  actual  details
# 0   1.0   13286    13286
# 1   2.0    7761     7761
# 2   3.0   10430    10430
# 3   4.0   14383    14383
# 4   5.0   23033    23033
# 5   6.0   49527    49527
# 6   7.0  171540   171540
# 7   8.0  577699   577699
# 8   9.0  601345   601345
# 9  10.0   81166    81166

# %%
df_actual_with_filter_9_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 9 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 9 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_10 = knn_basic.loc[knn_basic["actual"] == 10]
df_actual_with_filter_10_plot = round_est_values(df_actual_with_filter_10)
print(df_actual_with_filter_10_plot)
# Out:
#     est  actual  details
# 0   1.0   15309    15309
# 1   2.0    7084     7084
# 2   3.0    8474     8474
# 3   4.0   11435    11435
# 4   5.0   15980    15980
# 5   6.0   26455    26455
# 6   7.0   64543    64543
# 7   8.0  199193   199193
# 8   9.0  426136   426136
# 9  10.0  274374   274374

# %%
df_actual_with_filter_10_plot.plot.bar(x='est', y='actual', title="(Pearson Baseline) Actual 10 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson Baseline) Actual 10 counter (filter -1)'}, xlabel='est'>

# %%
round_df = np.round(knn_basic["est"], decimals=0)
round_df = round_df.reset_index()
knn_basic = knn_basic.reset_index()[["index", "actual", "details"]]
knn_basic = knn_basic.merge(round_df, on="index", how="left")
knn_basic = knn_basic.set_index("index")

# %%
est_df = knn_basic["est"].tolist()
plot_violin_graph_base(est_df, title="(Pearson Baseline) Estimation (filter -1)")

# %%
df_grouped = round_est_values(knn_basic)
print(df_grouped)
# Out:
#     est     actual    details
# 0   1.0   91763000   91763000
# 1   2.0    9104250    9104250
# 2   3.0    9254625    9254625
# 3   4.0   11915375   11915375
# 4   5.0   21577000   21577000
# 5   6.0   53561875   53561875
# 6   7.0  129179875  129179875
# 7   8.0  183576250  183576250
# 8   9.0  118640001  118640001
# 9  10.0   31877125   31877125

# %%
df_grouped.plot.bar(x='est', y='actual', title="Distribuição valores preditos (filtro -1) - knn_baseline")
# Out:
# <AxesSubplot:title={'center':'Distribuição valores preditos (filtro -1) - knn_baseline'}, xlabel='est'>
