# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def round_est_values(df):
    round_actual = np.round(df["est"], decimals=0)
    round_actual = round_actual.reset_index()
    df = df.reset_index()[["index", "actual", "details"]]
    df = df.merge(round_actual, on="index", how="left")
    df = df.set_index("index")
    grouped = df.groupby("est", as_index=False).count()
    return grouped

# %%
pearson_fold_0 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_0.parquet")
pearson_fold_1 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_1.parquet")
pearson_fold_2 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_2.parquet")
pearson_fold_3 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_3.parquet")
pearson_fold_4 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/no_filter/knn_baseline_pearson_4.parquet")

df = pd.concat([pearson_fold_0, pearson_fold_1, pearson_fold_2, pearson_fold_3, pearson_fold_4])

# %% [markdown]
# ### Pearson

# %% [markdown]
# Os gráficos são comparativo da nota real VS a nota predita. Filtrando cada nota real (de 1 a 10), quais são as notas preditas por cada algoritmo usando similaridade de pearson

# %%
df_grouped = round_est_values(df)
print(df_grouped)
# Out:
#     est   actual  details
# 0   1.0  3696671  3696671
# 1   2.0   425850   425850
# 2   3.0   427620   427620
# 3   4.0   543805   543805
# 4   5.0   950295   950295
# 5   6.0  2324815  2324815
# 6   7.0  5351580  5351580
# 7   8.0  7097990  7097990
# 8   9.0  4300585  4300585
# 9  10.0  1298765  1298765

# %%
df_grouped.plot.bar(x='est', y='actual', title="Distribuição valores preditos - KNN basic (knn_baseline)")
# Out:
# <AxesSubplot:title={'center':'Distribuição valores preditos - KNN basic (knn_baseline)'}, xlabel='est'>

# %%
df_actual_1 = df.loc[df["actual"] == 1]
plot_pearson_counter = round_est_values(df_actual_1)
print(plot_pearson_counter)
# Out:
#     est  actual  details
# 0   1.0     697      697
# 1   2.0     485      485
# 2   3.0     623      623
# 3   4.0    1011     1011
# 4   5.0    1357     1357
# 5   6.0    1540     1540
# 6   7.0    1387     1387
# 7   8.0     778      778
# 8   9.0     285      285
# 9  10.0      82       82

# %%
plot_pearson_counter.plot.bar(x='est', y='actual', title="(Pearson) Actual 1 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 1 counter'}, xlabel='est'>

# %%
df_actual_2 = df.loc[df["actual"] == 2]
plot_pearson_counter_2 = round_est_values(df_actual_2)
print(plot_pearson_counter_2)
# Out:
#     est  actual  details
# 0   1.0     345      345
# 1   2.0     337      337
# 2   3.0     844      844
# 3   4.0    1778     1778
# 4   5.0    2722     2722
# 5   6.0    3035     3035
# 6   7.0    2343     2343
# 7   8.0    1052     1052
# 8   9.0     321      321
# 9  10.0      57       57

# %%
plot_pearson_counter_2.plot.bar(x='est', y='actual', title="(Pearson) Actual 2 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 2 counter'}, xlabel='est'>

# %%
df_actual_3 = df.loc[df["actual"] == 3]
plot_pearson_counter_3 = round_est_values(df_actual_3)
print(plot_pearson_counter_3)
# Out:
#     est  actual  details
# 0   1.0     474      474
# 1   2.0     373      373
# 2   3.0    1026     1026
# 3   4.0    2938     2938
# 4   5.0    5556     5556
# 5   6.0    6713     6713
# 6   7.0    4832     4832
# 7   8.0    2019     2019
# 8   9.0     491      491
# 9  10.0      62       62

# %%
plot_pearson_counter_3.plot.bar(x='est', y='actual', title="(Pearson) Actual 3 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 3 counter'}, xlabel='est'>

# %%
df_actual_4 = df.loc[df["actual"] == 4]
plot_pearson_counter_4 = round_est_values(df_actual_4)
print(plot_pearson_counter_4)
# Out:
#     est  actual  details
# 0   1.0    1080     1080
# 1   2.0     728      728
# 2   3.0    1651     1651
# 3   4.0    4843     4843
# 4   5.0   12471    12471
# 5   6.0   19751    19751
# 6   7.0   16503    16503
# 7   8.0    6724     6724
# 8   9.0    1622     1622
# 9  10.0     220      220

# %%
plot_pearson_counter_4.plot.bar(x='est', y='actual', title="(Pearson) Actual 4 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 4 counter'}, xlabel='est'>

# %%
df_actual_5 = df.loc[df["actual"] == 5]
plot_pearson_counter_5 = round_est_values(df_actual_5)
print(plot_pearson_counter_5)
# Out:
#     est  actual  details
# 0   1.0    2803     2803
# 1   2.0    1848     1848
# 2   3.0    3112     3112
# 3   4.0    7896     7896
# 4   5.0   26069    26069
# 5   6.0   59503    59503
# 6   7.0   58945    58945
# 7   8.0   25007    25007
# 8   9.0    5594     5594
# 9  10.0     718      718

# %%
plot_pearson_counter_5.plot.bar(x='est', y='actual', title="(Pearson) Actual 5 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 5 counter'}, xlabel='est'>

# %%
df_actual_6 = df.loc[df["actual"] == 6]
plot_pearson_counter_6 = round_est_values(df_actual_6)
print(plot_pearson_counter_6)
# Out:
#     est  actual  details
# 0   1.0    5857     5857
# 1   2.0    3959     3959
# 2   3.0    5986     5986
# 3   4.0   11558    11558
# 4   5.0   36732    36732
# 5   6.0  129983   129983
# 6   7.0  202918   202918
# 7   8.0  102159   102159
# 8   9.0   21565    21565
# 9  10.0    2377     2377

# %%
plot_pearson_counter_6.plot.bar(x='est', y='actual', title="(Pearson) Actual 6 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 6 counter'}, xlabel='est'>

# %%
df_actual_7 = df.loc[df["actual"] == 7]
plot_pearson_counter_7 = round_est_values(df_actual_7)
print(plot_pearson_counter_7)
# Out:
#     est  actual  details
# 0   1.0   15807    15807
# 1   2.0   10437    10437
# 2   3.0   14697    14697
# 3   4.0   23790    23790
# 4   5.0   55071    55071
# 5   6.0  204906   204906
# 6   7.0  593864   593864
# 7   8.0  503360   503360
# 8   9.0  120694   120694
# 9  10.0   11824    11824

# %%
plot_pearson_counter_7.plot.bar(x='est', y='actual', title="(Pearson) Actual 7 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 7 counter'}, xlabel='est'>

# %%
df_actual_8 = df.loc[df["actual"] == 8]
plot_pearson_counter_8 = round_est_values(df_actual_8)
print(plot_pearson_counter_8)
# Out:
#     est  actual  details
# 0   1.0   21935    21935
# 1   2.0   14171    14171
# 2   3.0   19210    19210
# 3   4.0   27497    27497
# 4   5.0   49556    49556
# 5   6.0  144309   144309
# 6   7.0  534066   534066
# 7   8.0  951762   951762
# 8   9.0  384003   384003
# 9  10.0   42857    42857

# %%
plot_pearson_counter_8.plot.bar(x='est', y='actual', title="(Pearson) Actual 8 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 8 counter'}, xlabel='est'>

# %%
df_actua_9 = df.loc[df["actual"] == 9]
plot_pearson_counter_9 = round_est_values(df_actua_9)
print(plot_pearson_counter_9)
# Out:
#     est  actual  details
# 0   1.0   18462    18462
# 1   2.0   11089    11089
# 2   3.0   13695    13695
# 3   4.0   18422    18422
# 4   5.0   28896    28896
# 5   6.0   63895    63895
# 6   7.0  212314   212314
# 7   8.0  573653   573653
# 8   9.0  512028   512028
# 9  10.0   97382    97382

# %%
plot_pearson_counter_9.plot.bar(x='est', y='actual', title="(Pearson) Actual 9 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 9 counter'}, xlabel='est'>

# %%
df_actua_10 = df.loc[df["actual"] == 10]
plot_pearson_counter_10 = round_est_values(df_actua_10)
print(plot_pearson_counter_10)
# Out:
#     est  actual  details
# 0   1.0   19925    19925
# 1   2.0    9499     9499
# 2   3.0   10893    10893
# 3   4.0   14156    14156
# 4   5.0   19094    19094
# 5   6.0   33189    33189
# 6   7.0   83330    83330
# 7   8.0  228520   228520
# 8   9.0  377858   377858
# 9  10.0  252621   252621

# %%
plot_pearson_counter_10.plot.bar(x='est', y='actual', title="(Pearson) Actual 10 counter")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 10 counter'}, xlabel='est'>

# %%
round_df = np.round(df["est"], decimals=0)
round_df = round_df.reset_index()
df = df.reset_index()[["index", "actual", "details"]]
df = df.merge(round_df, on="index", how="left")

# %%
df = df.set_index("index")
plot_df = df.groupby("est", as_index=False).count()
print(plot_df)
# Out:
#     est   actual  details
# 0   1.0  3696671  3696671
# 1   2.0   425850   425850
# 2   3.0   427620   427620
# 3   4.0   543805   543805
# 4   5.0   950295   950295
# 5   6.0  2324815  2324815
# 6   7.0  5351580  5351580
# 7   8.0  7097990  7097990
# 8   9.0  4300585  4300585
# 9  10.0  1298765  1298765

# %%
def plot_violin_graph_base(list_of_data, title):
    # Create a figure instance
    fig = plt.figure()
  
    # Create an axes instance
    ax = fig.gca()
    ax.set_title(title)
    # Create the violinplot
    violinplot = ax.violinplot(list_of_data)
    plt.show()

# %% [markdown]
# Gráfico para o estudo de como está distribuição de notas preditas

# %%
est_df = df["est"].tolist()
plot_violin_graph_base(est_df, title="all folds estimation - knn_baseline")

# %% [markdown]
# é notório também que as notas reais estão amis concentradas entre 6 e 8, o que infuencia na predição. O algoritmo tende a acertar mais quando com essas notas e errar com notas entre 1 e 4

# %%
est_df = df["actual"].tolist()
plot_violin_graph_base(est_df, title="all folds actual - knn_baseline")

# %% [markdown]
# # Removing negative grades

# %% [markdown]
# ### Cossine

# %%
knn_basic_0 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_0.parquet")
knn_basic_1 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_1.parquet")
knn_basic_2 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_2.parquet")
knn_basic_3 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_3.parquet")
knn_basic_4 = pd.read_parquet(f"../predictions/knn_baseline/anime_type_tv/with_filter_remove_negative/knn_baseline_pearson_4.parquet")
knn_basic = pd.concat([knn_basic_0, knn_basic_1, knn_basic_2, knn_basic_3, knn_basic_4])

# %%
df_grouped = round_est_values(knn_basic)
print(df_grouped)
# Out:
#     est   actual  details
# 0   1.0  3697995  3697995
# 1   2.0   424380   424380
# 2   3.0   428260   428260
# 3   4.0   544645   544645
# 4   5.0   948925   948925
# 5   6.0  2326185  2326185
# 6   7.0  5352045  5352045
# 7   8.0  7103711  7103711
# 8   9.0  4294325  4294325
# 9  10.0  1297505  1297505

# %%
df_grouped.plot.bar(x='est', y='actual', title="Distribuição valores preditos (filtro -1) - KNN Basic (Pearson)")
# Out:
# <AxesSubplot:title={'center':'Distribuição valores preditos (filtro -1) - KNN Basic (Pearson)'}, xlabel='est'>

# %%
df_actual_with_filter_1 = knn_basic.loc[knn_basic["actual"] == 1]
df_actual_with_filter_1_plot = round_est_values(df_actual_with_filter_1)
print(df_actual_with_filter_1_plot)
# Out:
#     est  actual  details
# 0   1.0     706      706
# 1   2.0     489      489
# 2   3.0     630      630
# 3   4.0     943      943
# 4   5.0    1348     1348
# 5   6.0    1637     1637
# 6   7.0    1306     1306
# 7   8.0     814      814
# 8   9.0     315      315
# 9  10.0      81       81

# %%
df_actual_with_filter_1_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 1 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 1 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_2 = knn_basic.loc[knn_basic["actual"] == 2]
df_actual_with_filter_2_plot = round_est_values(df_actual_with_filter_2)
print(df_actual_with_filter_2_plot)
# Out:
#     est  actual  details
# 0   1.0     363      363
# 1   2.0     358      358
# 2   3.0     782      782
# 3   4.0    1796     1796
# 4   5.0    2652     2652
# 5   6.0    3128     3128
# 6   7.0    2355     2355
# 7   8.0    1044     1044
# 8   9.0     286      286
# 9  10.0      64       64

# %%
df_actual_with_filter_2_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 2 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 2 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_3 = knn_basic.loc[knn_basic["actual"] == 3]
df_actual_with_filter_3_plot = round_est_values(df_actual_with_filter_3)
print(df_actual_with_filter_3_plot)
# Out:
#     est  actual  details
# 0   1.0     483      483
# 1   2.0     388      388
# 2   3.0    1006     1006
# 3   4.0    3030     3030
# 4   5.0    5488     5488
# 5   6.0    6685     6685
# 6   7.0    4824     4824
# 7   8.0    2022     2022
# 8   9.0     471      471
# 9  10.0      87       87

# %%
df_actual_with_filter_3_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 3 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 3 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_4 = knn_basic.loc[knn_basic["actual"] == 4]
df_actual_with_filter_4_plot = round_est_values(df_actual_with_filter_4)
print(df_actual_with_filter_4_plot)
# Out:
#     est  actual  details
# 0   1.0    1089     1089
# 1   2.0     734      734
# 2   3.0    1610     1610
# 3   4.0    4921     4921
# 4   5.0   12265    12265
# 5   6.0   19881    19881
# 6   7.0   16278    16278
# 7   8.0    6941     6941
# 8   9.0    1610     1610
# 9  10.0     222      222

# %%
df_actual_with_filter_4_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 4 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 4 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_5 = knn_basic.loc[knn_basic["actual"] == 5]
df_actual_with_filter_5_plot = round_est_values(df_actual_with_filter_5)
print(df_actual_with_filter_5_plot)
# Out:
#     est  actual  details
# 0   1.0    2834     2834
# 1   2.0    1774     1774
# 2   3.0    3168     3168
# 3   4.0    7725     7725
# 4   5.0   26137    26137
# 5   6.0   59509    59509
# 6   7.0   58732    58732
# 7   8.0   25301    25301
# 8   9.0    5618     5618
# 9  10.0     699      699

# %%
df_actual_with_filter_5_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 5 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 5 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_6 = knn_basic.loc[knn_basic["actual"] == 6]
df_actual_with_filter_6_plot = round_est_values(df_actual_with_filter_6)
print(df_actual_with_filter_6_plot)
# Out:
#     est  actual  details
# 0   1.0    5895     5895
# 1   2.0    3907     3907
# 2   3.0    6043     6043
# 3   4.0   11907    11907
# 4   5.0   36518    36518
# 5   6.0  130009   130009
# 6   7.0  202768   202768
# 7   8.0  102246   102246
# 8   9.0   21194    21194
# 9  10.0    2413     2413

# %%
df_actual_with_filter_6_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 6 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 6 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_7 = knn_basic.loc[knn_basic["actual"] == 7]
df_actual_with_filter_7_plot = round_est_values(df_actual_with_filter_7)
print(df_actual_with_filter_7_plot)
# Out:
#     est  actual  details
# 0   1.0   15793    15793
# 1   2.0   10297    10297
# 2   3.0   14416    14416
# 3   4.0   23769    23769
# 4   5.0   55608    55608
# 5   6.0  204489   204489
# 6   7.0  593852   593852
# 7   8.0  504223   504223
# 8   9.0  120009   120009
# 9  10.0   11982    11982

# %%
df_actual_with_filter_7_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 7 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 7 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_8 = knn_basic.loc[knn_basic["actual"] == 8]
df_actual_with_filter_8_plot = round_est_values(df_actual_with_filter_8)
print(df_actual_with_filter_8_plot)
# Out:
#     est  actual  details
# 0   1.0   21777    21777
# 1   2.0   14088    14088
# 2   3.0   19129    19129
# 3   4.0   27691    27691
# 4   5.0   49454    49454
# 5   6.0  143798   143798
# 6   7.0  537610   537610
# 7   8.0  951970   951970
# 8   9.0  383032   383032
# 9  10.0   42679    42679

# %%
df_actual_with_filter_8_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 8 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 8 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_9 = knn_basic.loc[knn_basic["actual"] == 9]
df_actual_with_filter_9_plot = round_est_values(df_actual_with_filter_9)
print(df_actual_with_filter_9_plot)
# Out:
#     est  actual  details
# 0   1.0   18419    18419
# 1   2.0   11017    11017
# 2   3.0   13630    13630
# 3   4.0   18254    18254
# 4   5.0   29030    29030
# 5   6.0   64770    64770
# 6   7.0  211758   211758
# 7   8.0  572536   572536
# 8   9.0  513959   513959
# 9  10.0   96861    96861

# %%
df_actual_with_filter_9_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 9 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 9 counter (filter -1)'}, xlabel='est'>

# %%
df_actual_with_filter_10 = knn_basic.loc[knn_basic["actual"] == 10]
df_actual_with_filter_10_plot = round_est_values(df_actual_with_filter_10)
print(df_actual_with_filter_10_plot)
# Out:
#     est  actual  details
# 0   1.0   20065    20065
# 1   2.0    9427     9427
# 2   3.0   11020    11020
# 3   4.0   14406    14406
# 4   5.0   19060    19060
# 5   6.0   33184    33184
# 6   7.0   83219    83219
# 7   8.0  228119   228119
# 8   9.0  376935   376935
# 9  10.0  252864   252864

# %%
df_actual_with_filter_10_plot.plot.bar(x='est', y='actual', title="(Pearson) Actual 10 counter (filter -1)")
# Out:
# <AxesSubplot:title={'center':'(Pearson) Actual 10 counter (filter -1)'}, xlabel='est'>

# %%
round_df = np.round(knn_basic["est"], decimals=0)
round_df = round_df.reset_index()
knn_basic = knn_basic.reset_index()[["index", "actual", "details"]]
knn_basic = knn_basic.merge(round_df, on="index", how="left")
knn_basic = knn_basic.set_index("index")

# %%
est_df = knn_basic["est"].tolist()
plot_violin_graph_base(est_df, title="(Pearson) Estimation (filter -1) - knn_baseline")
